# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',235)
# pd.set_option('display.max_rows',235)

# %%
df=pd.read_csv(r"C:\YUG SAVLA\Coding\DJS_COMPUTE\Task_1\listings_data (1).csv")
df
# Out:
#        listing_id                                       listing_name  \
# 0            2539                 Clean & quiet apt home by the park
# 1            2595                              Skylit Midtown Castle
# 2            3647                THE VILLAGE OF HARLEM....NEW YORK !
# 3            3831                    Cozy Entire Floor of Brownstone
# 4            5022   Entire Apt: Spacious Studio/Loft by central park
# ...           ...                                                ...
# 48890    36484665    Charming one bedroom - newly renovated rowhouse
# 48891    36485057      Affordable room in Bushwick/East Williamsburg
# 48892    36485431            Sunny Studio at Historical Neighborhood
# 48893    36485609               43rd St. Time Square-cozy single bed
# 48894    36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#         host_id      host_name    borough                area  latitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   listing_id            48895 non-null  int64
#  1   listing_name          48879 non-null  object
#  2   host_id               48895 non-null  int64
#  3   host_name             48874 non-null  object
#  4   borough               48895 non-null  object
#  5   area                  48895 non-null  object
#  6   latitude              48895 non-null  float64
#  7   longitude             48895 non-null  float64
#  8   room_type             48895 non-null  object
#  9   price (in dollars)    48895 non-null  int64
#  10  minimum_stay          48895 non-null  int64
#  11  no_of_reviews         48895 non-null  int64
#  12  last_review_date      38843 non-null  object
#  13  reviews_per_month     38843 non-null  float64
#  14  host_listing_count    48895 non-null  int64
# ...

# %%
df[df['listing_name'].duplicated()]
# Out:
#        listing_id                                       listing_name  \
# 330         81739                  Loft w/ Terrace @ Box House Hotel
# 339         84010                               Superior @ Box House
# 580        219818                 ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿
# 661        250537                                The Lenox in Harlem
# 669        253471                   Loft Suite @ The Box House Hotel
# ...           ...                                                ...
# 48684    36382847                                       Comfort home
# 48735    36412461  Sunny, Cozy, Private Room In The Heart of Bush...
# 48759    36420404                                    Home Sweet Home
# 48791    36427922                                Home away from home
# 48826    36449743                                  Brooklyn's finest
#
#          host_id            host_name    borough             area  latitude  \
# ...

# %%
df.query('listing_name == "Superior @ Box House"')
# Out:
#      listing_id          listing_name  host_id            host_name   borough  \
# 321       77765  Superior @ Box House   417504  The Box House Hotel  Brooklyn
# 339       84010  Superior @ Box House   417504  The Box House Hotel  Brooklyn
# 682      253846  Superior @ Box House   417504  The Box House Hotel  Brooklyn
#
#            area  latitude  longitude     room_type  price (in dollars)  \
# 321  Greenpoint  40.73749  -73.95292  Private room                 179
# 339  Greenpoint  40.73813  -73.95394  Private room                 179
# 682  Greenpoint  40.73731  -73.95450  Private room                 179
#
#      minimum_stay  no_of_reviews last_review_date  reviews_per_month  \
# 321             3             36       01-07-2019               0.36
# 339             3             13       27-06-2019               0.14
# 682             3              4       04-12-2015               0.05
#
#      host_listing_count  booking_availability
# ...

# %%
df1=df.copy()
df1.drop_duplicates(subset='listing_name', inplace=True)

# %%
df.shape
# Out:
# (48895, 16)

# %%
df1.shape
# Out:
# (47897, 16)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47897 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   listing_id            47897 non-null  int64
#  1   listing_name          47896 non-null  object
#  2   host_id               47897 non-null  int64
#  3   host_name             47876 non-null  object
#  4   borough               47897 non-null  object
#  5   area                  47897 non-null  object
#  6   latitude              47897 non-null  float64
#  7   longitude             47897 non-null  float64
#  8   room_type             47897 non-null  object
#  9   price (in dollars)    47897 non-null  int64
#  10  minimum_stay          47897 non-null  int64
#  11  no_of_reviews         47897 non-null  int64
#  12  last_review_date      38177 non-null  object
#  13  reviews_per_month     38177 non-null  float64
#  14  host_listing_count    47897 non-null  int64
# ...

# %%
df2=df1.drop(columns=['latitude','longitude'])

# %%
df2.isnull().sum()
# Out:
# listing_id                 0
# listing_name               1
# host_id                    0
# host_name                 21
# borough                    0
# area                       0
# room_type                  0
# price (in dollars)         0
# minimum_stay               0
# no_of_reviews              0
# last_review_date        9720
# reviews_per_month       9720
# host_listing_count         0
# booking_availability       0
# dtype: int64

# %%
df2.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)

# %%
# df2['listing_name'].fillna(, inplace=True)
# df2['host_name'].fillna(, inplace=True)
mode_value = df2['listing_name'].mode()[0]
df2['listing_name'].fillna(mode_value, inplace=True)
mode_value = df2['host_name'].mode()[0]
df2['host_name'].fillna(mode_value, inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14012\893798436.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['listing_name'].fillna(mode_value, inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14012\893798436.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df2.isnull().sum()
# Out:
# listing_id                 0
# listing_name               0
# host_id                    0
# host_name                  0
# borough                    0
# area                       0
# room_type                  0
# price (in dollars)         0
# minimum_stay               0
# no_of_reviews              0
# last_review_date        9720
# reviews_per_month       9720
# host_listing_count         0
# booking_availability       0
# dtype: int64

# %%
df2['last_review_date']
# Out:
# 0        19-10-2018
# 1        21-05-2019
# 2               NaN
# 3        05-07-2019
# 4        19-11-2018
#             ...
# 48890           NaN
# 48891           NaN
# 48892           NaN
# 48893           NaN
# 48894           NaN
# Name: last_review_date, Length: 47897, dtype: object

# %%
median_value=df2['reviews_per_month'].median()
df2['reviews_per_month'].fillna(median_value,inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14012\3974862123.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['reviews_per_month'].fillna(median_value,inplace=True)

# %%
df2.isnull().sum()
# Out:
# listing_id                 0
# listing_name               0
# host_id                    0
# host_name                  0
# borough                    0
# area                       0
# room_type                  0
# price (in dollars)         0
# minimum_stay               0
# no_of_reviews              0
# last_review_date        9720
# reviews_per_month          0
# host_listing_count         0
# booking_availability       0
# dtype: int64

# %%
df2[['review_day','review_month', 'review_year']]=df2['last_review_date'].str.split('-', expand =True)
df2.drop('last_review_date', axis=1,inplace=True)
df2.head()
# Out:
#    listing_id                                      listing_name  host_id  \
# 0        2539                Clean & quiet apt home by the park     2787
# 1        2595                             Skylit Midtown Castle     2845
# 2        3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3        3831                   Cozy Entire Floor of Brownstone     4869
# 4        5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name    borough          area        room_type  price (in dollars)  \
# 0         John   Brooklyn    Kensington     Private room                 149
# 1     Jennifer  Manhattan       Midtown  Entire home/apt                 225
# 2    Elisabeth  Manhattan        Harlem     Private room                 150
# 3  LisaRoxanne   Brooklyn  Clinton Hill  Entire home/apt                  89
# 4        Laura  Manhattan   East Harlem  Entire home/apt                  80
#
# ...

# %%
df2['review_year'].value_counts()
# Out:
# review_year
# 2019    24814
# 2018     5916
# 2017     3148
# 2016     2657
# 2015     1365
# 2014      199
# 2013       48
# 2012       24
# 2011        6
# Name: count, dtype: int64

# %%
df2 = df2.dropna()

df2['review_day']=df2['review_day'].astype(int)
df2['review_year']=df2['review_year'].astype(int)
df2['review_month']=df2['review_month'].astype(int)

# %%
mean_value=int(np.mean(df2['review_day']))
df2['review_day'].fillna(mean_value,inplace=True)
mean_value=int(np.mean(df2['review_year']))
df2['review_year'].fillna(mean_value,inplace=True)

mean_value=int(np.mean(df2['review_month']))
df2['review_year'].fillna(mean_value,inplace=True)
df2.isnull().sum()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14012\1424671001.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['review_day'].fillna(mean_value,inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14012\1424671001.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df2.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df2.columns
# Out:
# Index(['listing_id', 'listing_name', 'host_id', 'host_name', 'borough', 'area',
#        'room_type', 'price (in dollars)', 'minimum_stay', 'no_of_reviews',
#        'reviews_per_month', 'host_listing_count', 'booking_availability',
#        'review_day', 'review_month', 'review_year'],
#       dtype='object')

# %%
frame=df2[['price (in dollars)','minimum_stay','no_of_reviews']]

frame.set_index('minimum_stay',inplace=True)
frame.reset_index(inplace=True)

frame.plot(kind='scatter', x='no_of_reviews', y='price (in dollars)')
plt.title('Scatter Plot of Price vs no_of_reviews')
plt.xlabel('no_of_reviews')
plt.ylabel('price (in dollars)')
plt.show()

# %%
group_area=df2.groupby('area')
group_area.plot()
plt.show()
